# %%
import pandas as pd
import numpy as np
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
df = pd.read_csv('/Users/fzarkhin/OneDrive - Advance Central Services, Inc/fproj/github/database-story/data/processed/complaints-after-state-updates.csv')
owners = pd.read_csv('/Users/fzarkhin/OneDrive - Advance Central Services, Inc/fproj/github/database-story/data/raw/APD_HistOwner.csv')
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# This notebook uses complaints and ownership history data to substantiate the following passage in The Oregonian's story: False Comfort

# %% [markdown]
# <i>"River Grove Memory Care in Eugene, for example, has only racked up three substantiated complaints under the current owners, who took over in 2015. However, the home had an additional 31 complaints under the four previous owners it has had since opening in 2000, including 16 that happened in the two years before the current owners took over.
#
# It would take a thorough knowledge of the home’s history to find them. River Grove used to be Santa Clara Special Care Community. Before that, Sierra Oaks of Santa Clara. Before that, Santa Clara Residential Inn."</i>

# %% [markdown]
# <h2>First, we must fix the ownership history table</h2>

# %%
owners.rename(columns={'HOW_IdNumber':'owner_id','HOW_CcmuNumber': 'fac_ccmunumber', 'HOW_DateActive':'license_date'}, inplace=True)
owners['license_date'] = pd.to_datetime(owners['license_date'])

# %%
owners = owners[['fac_ccmunumber','license_date','owner_id']]

# %% [markdown]
# <h3>When did River Grove open, when did the last owners take over, and how many companies have owned the facility?</h3>

# %%
#Last ownership change
owners[owners['fac_ccmunumber']=='50M132']
# Out:
#     fac_ccmunumber license_date  owner_id
# 570         50M132   2000-05-25       264
# 571         50M132   2005-05-07      1396
# 572         50M132   2008-09-19      1900
# 573         50M132   2009-07-01      1989
# 574         50M132   2015-04-01      2841

# %% [markdown]
# <h3>How many visible complaints have there been under the current ownership?</h3>

# %%
#Slice of public River Grove complaints
rg = df[(df['facility_id']=='50M132') & (df['public']=='online')]

# %%
rg[rg['incident_date']>='2015-04-01'].count()[0]
# Out:
# 2

# %% [markdown]
# <h3>How many online complaints have there been under previous ownership?</h3>

# %%
rg[rg['incident_date']<'2015-04-01'].count()[0]
# Out:
# 31

# %% [markdown]
# <h3>How many complaints occurred in the two years before the current owners took over?</h3>

# %%
rg[(rg['incident_date']<'2015-04-01') & (rg['incident_date']>'2013-04-01')].count()[0]
# Out:
# 17

# %% [markdown]
# <h3>What are the names River Grove is listed under on the public-facing website, and in what historical order?</h3>

# %%
rg[['incident_date','fac_name']].drop_duplicates(subset='fac_name', keep='first').sort_values('incident_date', ascending=False)
# Out:
#      incident_date                            fac_name
# 5291    2015-04-20             RIVER GROVE MEMORY CARE
# 5267    2014-11-02  SANTA CLARA SPECIAL CARE COMMUNITY
# 5321    2005-08-03          SIERRA OAKS OF SANTA CLARA
# 5320    2005-02-14         SANTA CLARA RESIDENTIAL INN

# %% [markdown]
# <h1>DONE</h1>
