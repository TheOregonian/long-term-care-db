# %%
import pandas as pd
import numpy as np
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
old = pd.read_csv('../../data/scraped/scraped_complaints_3_25.csv')

# %%
new = pd.read_csv('../../data/scraped/scraped_complaints_4_14.csv')

# %%
new.count()[0]
# Out:
# 6784

# %%
old.count()[0]
# Out:
# 6758

# %%
merged = new.merge(old,how = 'left',on='abuse_number')

# %%
merged.head()
# Out:
#   abuse_number city_name_x          fac_name_x fac_type_x inv_comp_date_x  \
# 0     OT104511     ONTARIO  AAREN BROOKE PLACE        RCF      06/25/2010
# 1    OT073945H     ONTARIO  AAREN BROOKE PLACE        RCF      06/18/2007
# 2    OT073945H     ONTARIO  AAREN BROOKE PLACE        RCF      06/18/2007
# 3    OT073945H     ONTARIO  AAREN BROOKE PLACE        RCF      06/18/2007
# 4    OT073945H     ONTARIO  AAREN BROOKE PLACE        RCF      06/18/2007
#
#   online_incident_date_x city_name_y          fac_name_y fac_type_y  \
# 0             05/19/2010     ONTARIO  AAREN BROOKE PLACE        RCF
# 1             02/12/2007     ONTARIO  AAREN BROOKE PLACE        RCF
# 2             02/12/2007     ONTARIO  AAREN BROOKE PLACE        RCF
# 3             02/12/2007     ONTARIO  AAREN BROOKE PLACE        RCF
# 4             02/12/2007     ONTARIO  AAREN BROOKE PLACE        RCF
#
#   inv_comp_date_y online_incident_date_y
# 0      06/25/2010             05/19/2010
# 1      06/18/2007             02/12/2007
# 2      06/18/2007             02/12/2007
# 3      06/18/2007             02/12/2007
# 4      06/18/2007             02/12/2007

# %%
merged2 = new.merge(old,how = 'right',on='abuse_number')

# %%
merged[merged['online_incident_date_y'].isnull()]#.count()
# Out:
#       abuse_number    city_name_x                                 fac_name_x  \
# 405       BO168079           BEND                    ASPEN RIDGE MEMORY CARE
# 584       NB179241     NORTH BEND                     BAYCREST ASSISTED CARE
# 585       NB167696     NORTH BEND                     BAYCREST ASSISTED CARE
# 896       ES152683         EUGENE                 CHURCHILL RESIDENTIAL CARE
# 897       ES147799         EUGENE                 CHURCHILL RESIDENTIAL CARE
# 898       ES147799         EUGENE                 CHURCHILL RESIDENTIAL CARE
# 899       ES147476         EUGENE                 CHURCHILL RESIDENTIAL CARE
# 900      ES117724C         EUGENE                 CHURCHILL RESIDENTIAL CARE
# 901       ES105476         EUGENE                 CHURCHILL RESIDENTIAL CARE
# 1427      HB166858       TUALATIN               FARMINGTON SQUARE - TUALATIN
# 1445      MS166524        MEDFORD                   FERN GARDENS MEMORY CARE
# 2218      KF166591  KLAMATH FALLS       PELICAN POINTE MEMORY CARE COMMUNITY
# 2305      ES179735         EUGENE          QUAIL PARK MEMORY CARE RESIDENCES
# 2813      HB166245         TIGARD             WASHINGTON GARDENS MEMORY CARE
# 2814      HB153658         TIGARD             WASHINGTON GARDENS MEMORY CARE
# 2815     HB152657C         TIGARD             WASHINGTON GARDENS MEMORY CARE
# 2816     HB152657A         TIGARD             WASHINGTON GARDENS MEMORY CARE
# 2817      HB150169         TIGARD             WASHINGTON GARDENS MEMORY CARE
# 2818      HB149186         TIGARD             WASHINGTON GARDENS MEMORY CARE
# 2819     HB149174A         TIGARD             WASHINGTON GARDENS MEMORY CARE
# 2820      HB148638         TIGARD             WASHINGTON GARDENS MEMORY CARE
# 2821      HB147200         TIGARD             WASHINGTON GARDENS MEMORY CARE
# 2822      HB146587         TIGARD             WASHINGTON GARDENS MEMORY CARE
# 2823      HB132686         TIGARD             WASHINGTON GARDENS MEMORY CARE
# 2824     HB132026X         TIGARD             WASHINGTON GARDENS MEMORY CARE
# 3273      MS168277    EAGLE POINT                      BROOKDALE EAGLE POINT
# 3283      ES168071         EUGENE            BROOKDALE EUGENE ALPINE SPRINGS
# 5463      MM168381        NEWBERG             CHEHALEM HEALTH & REHAB CENTER
# 5804      ES168100         EUGENE  GREEN VALLEY REHABILITATION HEALTH CENTER
# 6574  OR0001192300       PORTLAND                    PARK FOREST CARE CENTER
# 7092      BC168108       PORTLAND  WEST HILLS HEALTH & REHABILITATION CENTER
#
#      fac_type_x inv_comp_date_x online_incident_date_x city_name_y fac_name_y  \
# 405         RCF      11/09/2016             08/30/2016         NaN        NaN
# 584         RCF      03/08/2017             11/08/2016         NaN        NaN
# 585         RCF      12/15/2016             09/26/2016         NaN        NaN
# 896         RCF      10/30/2015             09/02/2015         NaN        NaN
# 897         RCF      08/26/2014             07/14/2014         NaN        NaN
# 898         RCF      08/26/2014             07/14/2014         NaN        NaN
# 899         RCF      07/08/2014             06/19/2014         NaN        NaN
# 900         RCF      06/06/2012             08/02/2011         NaN        NaN
# 901         RCF      03/10/2011             10/09/2010         NaN        NaN
# 1427        RCF      10/18/2016             07/29/2016         NaN        NaN
# 1445        RCF      11/10/2016             07/07/2016         NaN        NaN
# 2218        RCF      11/16/2016             07/10/2016         NaN        NaN
# 2305        RCF      03/21/2017             02/11/2017         NaN        NaN
# 2813        RCF      06/16/2016             06/15/2016         NaN        NaN
# 2814        RCF      03/10/2016             11/20/2015         NaN        NaN
# 2815        RCF      12/03/2015             09/01/2015         NaN        NaN
# 2816        RCF      12/03/2015             09/01/2015         NaN        NaN
# 2817        RCF      03/20/2015             02/05/2015         NaN        NaN
# 2818        RCF      11/08/2014             11/07/2014         NaN        NaN
# 2819        RCF      11/06/2014             11/06/2014         NaN        NaN
# 2820        RCF      12/08/2014             09/22/2014         NaN        NaN
# 2821        RCF      05/28/2014             05/27/2014         NaN        NaN
# 2822        RCF      06/04/2014             04/03/2014         NaN        NaN
# 2823        RCF      03/18/2013             03/15/2013         NaN        NaN
# 2824        RCF      01/12/2013             01/02/2013         NaN        NaN
# 3273        ALF      11/24/2016             11/04/2016         NaN        NaN
# 3283        ALF      11/15/2016             10/24/2016         NaN        NaN
# 5463        NF       12/29/2016             11/01/2016         NaN        NaN
# 5804        NF       03/08/2017             10/13/2016         NaN        NaN
# 6574        NF       02/27/2017             10/26/2016         NaN        NaN
# 7092        NF       03/02/2017             06/22/2016         NaN        NaN
#
#      fac_type_y inv_comp_date_y online_incident_date_y
# 405         NaN             NaN                    NaN
# 584         NaN             NaN                    NaN
# 585         NaN             NaN                    NaN
# 896         NaN             NaN                    NaN
# 897         NaN             NaN                    NaN
# 898         NaN             NaN                    NaN
# 899         NaN             NaN                    NaN
# 900         NaN             NaN                    NaN
# 901         NaN             NaN                    NaN
# 1427        NaN             NaN                    NaN
# 1445        NaN             NaN                    NaN
# 2218        NaN             NaN                    NaN
# 2305        NaN             NaN                    NaN
# 2813        NaN             NaN                    NaN
# 2814        NaN             NaN                    NaN
# 2815        NaN             NaN                    NaN
# 2816        NaN             NaN                    NaN
# 2817        NaN             NaN                    NaN
# 2818        NaN             NaN                    NaN
# 2819        NaN             NaN                    NaN
# 2820        NaN             NaN                    NaN
# 2821        NaN             NaN                    NaN
# 2822        NaN             NaN                    NaN
# 2823        NaN             NaN                    NaN
# 2824        NaN             NaN                    NaN
# 3273        NaN             NaN                    NaN
# 3283        NaN             NaN                    NaN
# 5463        NaN             NaN                    NaN
# 5804        NaN             NaN                    NaN
# 6574        NaN             NaN                    NaN
# 7092        NaN             NaN                    NaN
